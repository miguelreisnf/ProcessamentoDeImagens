# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelreisnf/ProcessamentoDeImagens/blob/main/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import cv2 #OpenCV
from google.colab.patches import cv2_imshow

# %%
arquivos = files.upload()
# Out:
#      <input type="file" id="files-404bcb2d-61fd-4a98-b216-9188c4dcf08d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-404bcb2d-61fd-4a98-b216-9188c4dcf08d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('wallpapersden.com_rising-sun-at-mountains-4k-background_300x300.jpg')
cv2_imshow(img)
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
# array([[[ 77,  49,  62],
#         [ 76,  48,  61],
#         [ 76,  48,  61],
#         ...,
#         [ 62,  32,  67],
#         [ 57,  31,  61],
#         [ 54,  30,  60]],
#
#        [[ 73,  49,  57],
#         [ 73,  50,  55],
#         [ 73,  50,  55],
#         ...,
#         [ 53,  29,  64],
#         [ 53,  28,  66],
#         [ 53,  26,  69]],
#
#        [[ 73,  50,  58],
#         [ 73,  50,  58],
#         [ 73,  50,  58],
#         ...,
#         [ 50,  26,  74],
#         [ 52,  26,  79],
#         [ 53,  26,  82]],
#
#        ...,
#
#        [[102,  71, 126],
#         [102,  71, 132],
#         [102,  71, 132],
#         ...,
#         [106,  79, 175],
#         [108,  80, 176],
#         [108,  82, 172]],
#
#        [[ 99,  70, 115],
#         [101,  71, 124],
#         [104,  72, 129],
#         ...,
#         [106,  78, 185],
#         [106,  81, 185],
#         [ 78,  49,  98]],
#
#        [[102,  73, 118],
# ...

# %%
img.shape
print(img)
# Out:
# [[[ 77  49  62]
#   [ 76  48  61]
#   [ 76  48  61]
#   ...
#   [ 62  32  67]
#   [ 57  31  61]
#   [ 54  30  60]]
#
#  [[ 73  49  57]
#   [ 73  50  55]
#   [ 73  50  55]
#   ...
#   [ 53  29  64]
#   [ 53  28  66]
#   [ 53  26  69]]
#
#  [[ 73  50  58]
#   [ 73  50  58]
#   [ 73  50  58]
#   ...
#   [ 50  26  74]
#   [ 52  26  79]
#   [ 53  26  82]]
#
#  ...
#
#  [[102  71 126]
#   [102  71 132]
#   [102  71 132]
#   ...
#   [106  79 175]
#   [108  80 176]
#   [108  82 172]]
#
#  [[ 99  70 115]
#   [101  71 124]
#   [104  72 129]
#   ...
#   [106  78 185]
#   [106  81 185]
#   [ 78  49  98]]
#
#  [[102  73 118]
#   [102  74 120]
#   [103  74 124]
#   ...
#   [105  82 188]
#   [ 99  72 152]
#   [ 53  25  38]]]

# %%
cv2_imshow(255 - img)
cv2_imshow(img*2)
cv2_imshow(img/4)
cv2_imshow((img/255) * 400)
cv2_imshow(img/0.5)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
B, G, R = cv2.split(img)
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
